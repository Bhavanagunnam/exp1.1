# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavanagunnam/exp1.1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv("/content/ACTIVITY.CSV")
dataset
# Out:
#     AGE SALARY
# 0    50  50000
# 1    40  60000
# 2    55  55000
# 3   NAN  66000
# 4    30    NAN
# 5    70  40000
# 6    30  70000
# 7   NAN  40000
# 8    60    NAN
# 9    25  80000
# 10  NAN  50000

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
print('independent variable(x):',x)
print('dependent variable(y)',y)
# Out:
# independent variable(x): [['50']
#  ['40']
#  ['55']
#  ['NAN']
#  ['30']
#  ['70']
#  ['30']
#  ['NAN']
#  ['60']
#  ['25']
#  ['NAN']]
# dependent variable(y) ['50000' '60000' '55000' '66000' 'NAN' '40000' '70000' '40000' 'NAN'
#  '80000' '50000']

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.NAN,strategy="mean")
x=imp.fit_transform(x)
y=y.reshape(-1,1)
y=imp.fit_transform(y)
y=y.reshape(-1)
print(x)
print(y)
# Out:
# [[50.]
#  [40.]
#  [55.]
#  [45.]
#  [30.]
#  [70.]
#  [30.]
#  [45.]
#  [60.]
#  [25.]
#  [45.]]
# [50000.         60000.         55000.         66000.
#  56777.77777778 40000.         70000.         40000.
#  56777.77777778 80000.         50000.        ]

# %%
x_df=pd.DataFrame(x,columns=dataset.columns[:-1])
y_df=pd.DataFrame(y,columns=[dataset.columns[-1]])
combined_data=pd.concat([x_df,y_df],axis=1)
print("combined data:")
print(combined_data)
# Out:
# combined data:
#      AGE        SALARY
# 0   50.0  50000.000000
# 1   40.0  60000.000000
# 2   55.0  55000.000000
# 3   45.0  66000.000000
# 4   30.0  56777.777778
# 5   70.0  40000.000000
# 6   30.0  70000.000000
# 7   45.0  40000.000000
# 8   60.0  56777.777778
# 9   25.0  80000.000000
# 10  45.0  50000.000000

# %%
combined_df=pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/ACTIVITY.CSV.xlsx",index=False)
print("combined dataframe:")
print(combined_df.head())
# Out:
# combined dataframe:
#     AGE        SALARY
# 0  50.0  50000.000000
# 1  40.0  60000.000000
# 2  55.0  55000.000000
# 3  45.0  66000.000000
# 4  30.0  56777.777778
